# %% [markdown]
# Representasi Graf dengan Adjacency List

# %%
# Membuat graf tak berarah menggunakan adjacency List
graph = {
    'A' : ['B', 'C'],
    'B' : ['A', 'D', 'E'],
    'C' : ['A', 'F'],
    'D' : ['B'],
    'E' : ['B', 'F'],
    'F' : ['C', 'E']
}

# Menampilkan graf
def print_graph(graf):
  for node in graf:
    print(f"{node} -> {graf[node]}")

print_graph(graph)
# Out:
# A -> ['B', 'C']
# B -> ['A', 'D', 'E']
# C -> ['A', 'F']
# D -> ['B']
# E -> ['B', 'F']
# F -> ['C', 'E']

# %% [markdown]
#  Traversal graf menggunakan BFS

# %%
from collections import deque

def bfs(graph, start) :
  visited = set()
  queue = deque([start])

  while queue:
    vertex = queue.popleft()
    if vertex not in visited:
      print(vertex, end=" ")
      visited.add(vertex)
      queue.extend([neighbor for neighbor in graph[vertex] if neighbor not in visited])

# Contoh pemanggilan
bfs(graph, 'A')
# Out:
# A B C D E F

# %% [markdown]
# Travelsal Graf menggunakan DFS

# %%
def dfs(graph, start, visited=None):
  if visited is None:
    visited = set ()

  if start not in visited:
    print(start, end=" ")
    visited.add(start)
    for neighbor in graph[start]:
      dfs(graph, neighbor, visited)

# Contoh pemanggilan
dfs(graph, 'A')
# Out:
# A B D E F C

# %% [markdown]
# Uji Pemahaman

# %%
# Lengkapi fungsi untuk menghitung jumlah tetangga dari tiap simpul dalam graf
def count_neighbors(graph):
    result = {}

    for node in graph:
        # Menghitung jumlah tetangga setiap simpul
        result[node] = len(graph[node])

    return result


# Contoh graf
graph = {
    'A': ['B', 'C'],
    'B': ['A', 'D'],
    'C': ['A'],
    'D': ['B']
}

# Menampilkan hasil
print(count_neighbors(graph))
# Out:
# {'A': 2, 'B': 2, 'C': 1, 'D': 1}

# %% [markdown]
# TUGAS

# %% [markdown]
# Soal 1 Membuat Graf Tak Berarah

# %%
graph = {
    'A': ['B', 'C', 'D'],
    'B': ['A', 'C', 'E'],
    'C': ['A', 'B', 'D', 'E'],
    'D': ['A', 'C', 'E'],
    'E': ['B', 'C', 'D']
}

def print_graph(graph):
    for node in graph:
        print(node, "->", graph[node])

print_graph(graph)
# Out:
# A -> ['B', 'C', 'D']
# B -> ['A', 'C', 'E']
# C -> ['A', 'B', 'D', 'E']
# D -> ['A', 'C', 'E']
# E -> ['B', 'C', 'D']

# %% [markdown]
# Soal 2 Implementasi BFS dan DFS

# %% [markdown]
# BFS

# %%
from collections import deque

def bfs(graph, start):
    visited = set()
    queue = deque([start])

    while queue:
        node = queue.popleft()

        if node not in visited:
            print(node, end=" ")
            visited.add(node)

            for neighbor in graph[node]:
                if neighbor not in visited:
                    queue.append(neighbor)

# Menjalankan BFS
bfs(graph, 'A')
# Out:
# A B C D E

# %% [markdown]
# DFS

# %%
def dfs(graph, node, visited=None):
    if visited is None:
        visited = set()

    if node not in visited:
        print(node, end=" ")
        visited.add(node)

        for neighbor in graph[node]:
            dfs(graph, neighbor, visited)

# Menjalankan DFS
dfs(graph, 'A')
# Out:
# A B C D E

# %% [markdown]
# Soal 3 Modifikasi BFS Mengembalikan List

# %%
from collections import deque

# Membuat graph
graph = {
    'A': ['B', 'C', 'D'],
    'B': ['A', 'E'],
    'C': ['A', 'F'],
    'D': ['A', 'E'],
    'E': ['B', 'D', 'F'],
    'F': ['C', 'E']
}

def bfs_list(graph, start):
    visited = set()
    queue = deque([start])
    result = []

    while queue:
        node = queue.popleft()

        if node not in visited:
            visited.add(node)
            result.append(node)

            for neighbor in graph[node]:
                if neighbor not in visited:
                    queue.append(neighbor)

    return result

# Menampilkan hasil
print(bfs_list(graph, 'A'))
# Out:
# ['A', 'B', 'C', 'D', 'E', 'F']

# %% [markdown]
# Soal 4 Fungsi find_path() Menggunakan DFS

# %%
def find_path(graph, start, end, path=[]):
    path = path + [start]

    if start == end:
        return path

    for neighbor in graph[start]:
        if neighbor not in path:
            new_path = find_path(graph, neighbor, end, path)

            if new_path:
                return new_path

    return None

# Contoh penggunaan
print(find_path(graph, 'A', 'E'))
# Out:
# ['A', 'B', 'E']

# %% [markdown]
# Soal 5 Fungsi is_connected()

# %%
def is_connected(graph):
    visited = set()

    def dfs(node):
        if node not in visited:
            visited.add(node)

            for neighbor in graph[node]:
                dfs(neighbor)

    first_node = next(iter(graph))
    dfs(first_node)

    return len(visited) == len(graph)

# Menampilkan hasil
print(is_connected(graph))
# Out:
# True
